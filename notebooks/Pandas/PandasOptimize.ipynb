# %%
import pandas as pd
import numpy as np

import sys
#sys.path.insert(0, '/home/jmeline/Projects/ODMToolsPython/odmtools')
sys.path.insert(0, "D:\DEV\ODMTools\ODMToolsPython\odmtools")
#from odmdata import SessionFactory
from odmservices import ServiceManager
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-61245583aed4> in <module>()
#       6 sys.path.insert(0, "D:\DEV\ODMTools\ODMToolsPython\odmtools")
#       7 #from odmdata import SessionFactory
# ----> 8 from odmservices import ServiceManager
#       9 from datetime import datetime
#
# ImportError: No module named odmservices

# %%
sm = ServiceManager()
sm._current_conn_dict= {'engine':'mssql', 'user':'webapplication' , 'password':'W3bAppl1c4t10n!', 'address':'iutahdbs.uwrl.usu.edu', 'db':'iUTAH_Logan_OD'}
#sm._current_conn_dict= {'engine': 'mysql', 'password': u'zxc', 'db': u'odm', 'user': u'root', 'address': u'localhost'}
ss = sm.get_series_service()
dvs = ss.get_series_by_id(173)
#s= ss.get_series_by_id(20)
#db = db + [x.list_repr() for x in dvs]

db= [x.list_repr() for x in dvs.data_values]
datelist=[ x.local_date_time for x in dvs.data_values]
dates = pd.Series(datelist)

df = pd.DataFrame(db, index = dates, columns = ["ValueID"
#df = pd.DataFrame(db,  columns = ["ValueID"
      ,"DataValue"
      ,"ValueAccuracy"
      ,"LocalDateTime"
      ,"UTCOffset"
      ,"DateTimeUTC"
      ,"SiteID"
      ,"VariableID"
      ,"OffsetValue"
      ,"OffsetTypeID"
      ,"CensorCode"
      ,"QualifierID"
      ,"MethodID"
      ,"SourceID"
      ,"SampleID"
      ,"DerivedFromID"
      ,"QualityControlLevelID"])
df.set_index(["LocalDateTime"], inplace=True)

df
# Out:
#                      ValueID  DataValue ValueAccuracy  UTCOffset  \
# LocalDateTime
# 2005-08-04 11:30:00  3034095   13.24467          None         -7
# 2005-08-04 12:00:00  3034096   13.20857          None         -7
# 2005-08-04 12:30:00  3034097   13.20605          None         -7
# 2005-08-04 13:00:00  3034098   13.20102          None         -7
# 2005-08-04 13:30:00  3034099   13.18003          None         -7
# 2005-08-04 14:00:00  3034100   13.17919          None         -7
# 2005-08-04 14:30:00  3034101   13.17415          None         -7
# 2005-08-04 15:00:00  3034102   13.15736          None         -7
# 2005-08-04 15:30:00  3034103   13.16072          None         -7
# 2005-08-04 16:00:00  3034104   13.15653          None         -7
# 2005-08-04 16:30:00  3034105   13.15317          None         -7
# 2005-08-04 17:00:00  3034106   13.16744          None         -7
# 2005-08-04 17:30:00  3034107   13.17080          None         -7
# ...

# %%
df.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2005-08-04 11:30:00, ..., 2006-02-28 19:00:00]
# Length: 10000, Freq: None, Timezone: None

# %%
#df.ix["2013-10-02":"2014-11-01"]
#dt= datetime(2013,10,2,17,45,0)
#df[dt:]
import time
start = time.clock()
df["2013-10-2 17:30":"2013-10-2 17:30"]
end = time.clock()
start2= time.clock()
4df.loc["2005-08-04 11:30:00"]
end2 = time.clock()
94834, 12.98864, 13.304270000000001, 13.32105, 13.290839999999999, 13.281599999999999, 13.274050000000001, 13.27656, 13.275729999999999, 13.26397, 13.25726, 13.259779999999999, 13.25726, 13.27824, 13.19262, 13.13386, 13.114549999999999, 13.089370000000001, 13.07258, 13.06587, 13.053269999999999, 13.044040000000001, 13.03397, 13.029769999999999, 13.01214, 13.007099999999999, 13.00207, 12.997870000000001, 12.99451, 12.98696, 12.982760000000001, 12.97772, 12.968489999999999, 12.96597, 12.9559, 12.96261, 12.95086, 12.95002, 12.94666, 12.9475, 12.97772, 12.95926, 13.051600000000001, 13.180870000000001, 13.190939999999999, 13.25306, 13.20773, 13.150650000000001, 13.12379, 13.091049999999999, 13.08853, 13.074260000000001, 13.058310000000001, 13.04824, 13.044040000000001, 13.037319999999999, 13.02054, 13.0197, 13.01046, 13.00459, 12.991989999999999, 12.984439999999999, 12.967650000000001, 12.967650000000001, 12.95926, 12.9559, 12.954219999999999, 12.954219999999999, 12.94415, 12.94247, 12.937430000000001, 12.94079, 12.93491, 12.931559999999999, 12.92736, 13.00459, 12.97017, 12.97185, 12.96346, 12.960940000000001, 12.953379999999999]][0]
df = pd.DataFrame(points, columns = ["DataValue"])
values = df['DataValue'].tolist()
#', '.join(map(str, values))

#df['rank'] = df.rank(method='max')


#First, I sort the values.
# sorted <- sort(TSSpred)
df.sort(kind='quicksort')

#Then, I rank the sorted values.
# ranks <- rank(sorted, ties.method="max")
ranks = df['DataValue'].rank()

#Then, I reverse the ranking.
# ranks <- max(ranks)-ranks

#This is the actual formula- rank/(length+1) as a %
# PrbExc = ranks/(length(sorted)+1)*100

## Probability plot


df['rank'] = df['DataValue'].rank()

df['PrbExc'] = ranks/(len(ranks)+1)*100
#df.set_index('DataValue')
df.plot(x='PrbExc', y='DataValue', kind="scatter", xlim=(1, 100))

#print PrbExc

#import matplotlib.pyplot as plt
#plt.plot(PrbExc, df['DataValue'])

#Here I plot the probability of exceedance (PrbExc) against the sorted initial values (sorted).
# plot(PrbExc, sorted, type='n', col='white', font.lab=1.5, xlab="Frequency of Exceedance, percent", ylab="TSS, mg/L",log="y")

# %%
import datetime
import pprint
x= [
 [0,datetime.datetime(2015,1,1),1,1,1,0],
 [1,datetime.datetime(2015,1,2),0,0,0,1],
 [1,datetime.datetime(2015,1,3),0,0,1,1],
 [0,datetime.datetime(2015,1,4),1,0,0,0],
 [0,datetime.datetime(2015,1,5),0,1,0,0],
 [0,datetime.datetime(2015,1,6),1,1,1,0],
 [0,datetime.datetime(2015,1,7),1,1,1,0],
 [1,datetime.datetime(2015,1,8),0,0,0,1],
 [1,datetime.datetime(2015,1,9),0,0,1,1],
 [0,datetime.datetime(2015,1,10),1,0,0,0],
 [0,datetime.datetime(2015,1,11),0,1,0,0],
 [0,datetime.datetime(2015,1,12),1,1,1,0],
 [0,datetime.datetime(2015,1,13),1,1,1,0],
 [1,datetime.datetime(2015,1,14),0,0,0,1],
 [1,datetime.datetime(2015,1,15),0,0,1,1],
 [0,datetime.datetime(2015,1,16),1,0,0,0],
 [0,datetime.datetime(2015,1,17),0,1,0,0],
 [0,datetime.datetime(2015,1,18),1,1,1,0],
 [0,datetime.datetime(2015,1,19),1,1,1,0],
 [1,datetime.datetime(2015,1,20),0,0,0,1],
 [1,datetime.datetime(2015,1,21),0,0,1,1],
 [0,datetime.datetime(2015,1,22),1,0,0,0],
 [0,datetime.datetime(2015,1,23),0,1,0,0],
 [0,datetime.datetime(2015,1,24),1,1,1,0],
 [1,datetime.datetime(2015,1,25),0,0,0,1]
 ]

## Nice printing
pp = pprint.PrettyPrinter(indent=2)

df = pd.DataFrame(x, columns = ['1', '2', '3', '4', '5', '6'])

#df.set_index('2', inplace=True)
#df.values.flatten()

l = list(df.values.tolist())

#print df
#pp.pprint(x)

## Converting to datetime from timestamp
print df[df["2"] < datetime.datetime(2015, 1, 13)]
"""
for i in l:
    i[1] = i[1].to_pydatetime()
    i[1]= pd.Timestamp(i[1])
    print i[1], type(i[1])
    
""" 
    
    
#df['2'].to_pydatetime()
# Out:
#     1          2  3  4  5  6
# 0   0 2015-01-01  1  1  1  0
# 1   1 2015-01-02  0  0  0  1
# 2   1 2015-01-03  0  0  1  1
# 3   0 2015-01-04  1  0  0  0
# 4   0 2015-01-05  0  1  0  0
# 5   0 2015-01-06  1  1  1  0
# 6   0 2015-01-07  1  1  1  0
# 7   1 2015-01-08  0  0  0  1
# 8   1 2015-01-09  0  0  1  1
# 9   0 2015-01-10  1  0  0  0
# 10  0 2015-01-11  0  1  0  0
# 11  0 2015-01-12  1  1  1  0
# '\nfor i in l:\n    i[1] = i[1].to_pydatetime()\n    i[1]= pd.Timestamp(i[1])\n    print i[1], type(i[1])\n    \n'

# %%
import pprint
points = [
[datetime.datetime(2005, 8, 12, 8, 0), datetime.datetime(2005, 8, 12, 8, 30), datetime.datetime(2005, 8, 12, 9, 0), datetime.datetime(2005, 8, 26, 1, 0), datetime.datetime(2005, 8, 26, 1, 30), datetime.datetime(2005, 8, 26, 2, 0), datetime.datetime(2005, 8, 26, 2, 30), datetime.datetime(2005, 8, 26, 3, 0), datetime.datetime(2005, 8, 26, 3, 30), datetime.datetime(2005, 8, 26, 4, 0), datetime.datetime(2005, 8, 26, 4, 30), datetime.datetime(2005, 8, 26, 5, 0), datetime.datetime(2005, 8, 26, 5, 30), datetime.datetime(2005, 8, 26, 6, 0)]][0]
results = pd.DataFrame(points, columns=["LocalDateTime"])
print results
# Out:
#          LocalDateTime
# 0  2005-08-12 08:00:00
# 1  2005-08-12 08:30:00
# 2  2005-08-12 09:00:00
# 3  2005-08-26 01:00:00
# 4  2005-08-26 01:30:00
# 5  2005-08-26 02:00:00
# 6  2005-08-26 02:30:00
# 7  2005-08-26 03:00:00
# 8  2005-08-26 03:30:00
# 9  2005-08-26 04:00:00
# 10 2005-08-26 04:30:00
# 11 2005-08-26 05:00:00
# 12 2005-08-26 05:30:00
# 13 2005-08-26 06:00:00

# %%
## Date Gap Testing... ##

import datetime
import pandas as pd
import numpy as np

points = [
    [datetime.datetime(2005, 8, 4, 16, 0), datetime.datetime(2005, 8, 4, 16, 30), 
     datetime.datetime(2005, 8, 4, 17, 0), datetime.datetime(2005, 8, 4, 17, 30), 
     datetime.datetime(2005, 8, 4, 18, 0), datetime.datetime(2005, 8, 4, 18, 30), 
     datetime.datetime(2005, 8, 4, 19, 15), datetime.datetime(2005, 8, 4, 19, 30), 
     datetime.datetime(2005, 8, 4, 20, 0), datetime.datetime(2005, 8, 4, 20, 30), 
     datetime.datetime(2005, 8, 4, 21, 0), datetime.datetime(2005, 8, 4, 21, 30), 
     datetime.datetime(2005, 8, 4, 22, 0), datetime.datetime(2005, 8, 4, 22, 30), 
     datetime.datetime(2005, 8, 4, 23, 0), datetime.datetime(2005, 8, 4, 23, 30), 
     datetime.datetime(2005, 8, 5, 0, 0), datetime.datetime(2005, 8, 5, 0, 30), 
     datetime.datetime(2005, 8, 5, 1, 0), datetime.datetime(2005, 8, 5, 1, 30), 
     datetime.datetime(2005, 8, 5, 2, 0), datetime.datetime(2005, 8, 5, 2, 30), 
     datetime.datetime(2005, 8, 5, 3, 0), datetime.datetime(2005, 8, 5, 3, 30), 
     datetime.datetime(2005, 8, 5, 4, 0), datetime.datetime(2005, 8, 5, 4, 30), 
     datetime.datetime(2005, 8, 5, 5, 0), datetime.datetime(2005, 8, 5, 5, 30), 
     datetime.datetime(2005, 8, 5, 6, 0), datetime.datetime(2005, 8, 5, 6, 30), 
     datetime.datetime(2005, 8, 5, 7, 0), datetime.datetime(2005, 8, 5, 7, 30), 
     datetime.datetime(2005, 8, 5, 8, 0), datetime.datetime(2005, 8, 5, 8, 30), 
     datetime.datetime(2005, 8, 5, 9, 0), datetime.datetime(2005, 8, 5, 9, 30), 
     datetime.datetime(2005, 8, 5, 10, 0), datetime.datetime(2005, 8, 5, 10, 30), 
     datetime.datetime(2005, 8, 5, 11, 0), datetime.datetime(2005, 8, 5, 11, 30), 
     datetime.datetime(2005, 8, 5, 12, 0), datetime.datetime(2005, 8, 5, 12, 30), 
     datetime.datetime(2005, 8, 5, 13, 0), datetime.datetime(2005, 8, 5, 13, 30), 
     datetime.datetime(2005, 8, 5, 14, 0), datetime.datetime(2005, 8, 5, 14, 30), 
     datetime.datetime(2005, 8, 5, 15, 0), datetime.datetime(2005, 8, 5, 15, 30), 
     datetime.datetime(2005, 8, 5, 16, 0), datetime.datetime(2005, 8, 5, 16, 30), 
     datetime.datetime(2005, 8, 5, 17, 0), datetime.datetime(2005, 8, 5, 17, 30), 
     datetime.datetime(2005, 8, 5, 18, 0), datetime.datetime(2005, 8, 5, 18, 30), 
     datetime.datetime(2005, 8, 5, 19, 0), datetime.datetime(2005, 8, 5, 19, 30), 
     datetime.datetime(2005, 8, 5, 20, 0), datetime.datetime(2005, 8, 5, 20, 30), 
     datetime.datetime(2005, 8, 5, 21, 0), datetime.datetime(2005, 8, 5, 21, 30), 
     datetime.datetime(2005, 8, 5, 22, 0), datetime.datetime(2005, 8, 5, 22, 30), 
     datetime.datetime(2005, 8, 5, 23, 0), datetime.datetime(2005, 8, 5, 23, 30), 
     datetime.datetime(2005, 8, 6, 0, 0), datetime.datetime(2005, 8, 6, 0, 30), 
     datetime.datetime(2005, 8, 6, 1, 0), datetime.datetime(2005, 8, 6, 1, 30), 
     datetime.datetime(2005, 8, 6, 2, 0), datetime.datetime(2005, 8, 6, 2, 30), 
     datetime.datetime(2005, 8, 6, 3, 0), datetime.datetime(2005, 8, 6, 3, 30), 
     datetime.datetime(2005, 8, 6, 4, 0), datetime.datetime(2005, 8, 6, 4, 30), 
     datetime.datetime(2005, 8, 6, 5, 0), datetime.datetime(2005, 8, 6, 5, 30), 
     datetime.datetime(2005, 8, 6, 6, 0), datetime.datetime(2005, 8, 6, 6, 30), 
     datetime.datetime(2005, 8, 6, 7, 0), datetime.datetime(2005, 8, 6, 7, 30)]
][0]

df = pd.DataFrame(points, columns=["datetime"])
demoValue = 30
timePeriod = u'minute'

value = demoValue*10
pd.options.display.max_rows = 999
df['dateprev'] = df['datetime'].shift()
#df['delta'] = (df["datetime"]-df["datetime"].shift())#.fillna(0)
#df['diff'].fillna(True)
df['diff'] = df["datetime"].diff().fillna(0)

df['greaterThan'] = df['diff'] >= np.timedelta64(demoValue, 'm')
#df['ans'] = df['delta'].apply(lambda x: x / np.timedelta64(1, 'm')).astype('int64')%(24*60)
#df[df['greaterThan']]
df = df[df['greaterThan']]
#print df
newdf = pd.concat([df['datetime'], df['dateprev']], join='inner')
print newdf.drop_duplicates().dropna().tolist()



#df["datetime"].diff().fillna(0)
#df[df['diff']]
#df['result'] = df['diff'].apply(lambda x: 1 if x else 0).cumsum()



### Online Example  of DataGaps in Pandas
### https://stackoverflow.com/questions/13976491/split-a-series-on-time-gaps-in-pandas?rq=1

#rng2011 = pd.date_range('1/1/2011', periods=72, freq='H')
#rng2012 = pd.date_range('1/1/2012', periods=72, freq='H')
#Y = rng2011.union(rng2012)

#df = pd.DataFrame(Y)
#df[1] = df[0].diff()
#df[1] = df[1].apply(lambda x: 1 if x else 0).cumsum()
#df
# Out:
# [Timestamp('2005-08-04 16:30:00'), Timestamp('2005-08-04 17:00:00'), Timestamp('2005-08-04 17:30:00'), Timestamp('2005-08-04 18:00:00'), Timestamp('2005-08-04 18:30:00'), Timestamp('2005-08-04 19:15:00'), Timestamp('2005-08-04 20:00:00'), Timestamp('2005-08-04 20:30:00'), Timestamp('2005-08-04 21:00:00'), Timestamp('2005-08-04 21:30:00'), Timestamp('2005-08-04 22:00:00'),