# %%
from odm2api.ODM2.models import *
from odm2api.ODMconnection import dbconnection
import sys 
# sys.path.append("D:\DEV\YODA-Tools\src")
# from YAML.yamlFunctions import YamlFunctions


#create db connection 
session_factory = dbconnection.createConnection('mysql', "wpfweb.uwrl.usu.edu", 'odm2_websdl', 'webuser', 'odm')
_session = session_factory.getSession()
_engine = session_factory.engine
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-1-92535fb64897> in <module>()
#       9
#      10 #create db connection
# ---> 11 session_factory = dbconnection.createConnection('mysql', "wpfweb.uwrl.usu.edu", 'odm2_websdl', 'webuser', 'odm')
#      12 _session = session_factory.getSession()
#      13 _engine = session_factory.engine
#
# /Users/stephanie/DEV/ODM2PythonAPI/odm2api/ODMconnection.pyc in createConnection(self, engine, address, db, user, password, dbtype, echo)
#      61         else:
#      62             connection_string = dbconnection.__buildConnectionString(dbconnection(), engine, address, db, user, password)
# ---> 63             if self.isValidConnection(connection_string, dbtype):
#      64                 return self.createConnectionFromString(connection_string, dbtype, echo)
#      65             else:
#
# ...
